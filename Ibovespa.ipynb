# %% [markdown]
# <a href="https://colab.research.google.com/github/carolhr/Ibovespa/blob/master/Ibovespa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# O que é índice Ibovespa
# Import pacotes e install yfinance
# Obtendo Dados
# Filter tabela
# plot Gráficos Open, Volume e Close
# Conclusão

# %% [markdown]
# **Índice Ibovespa**
#
# Índice Bovespa (Ibovespa) é o mais importante indicador do desempenho médio das cotações das ações negociadas na B3 - Brasil, Bolsa, Balcão. É formado pelas ações com maior volume negociado nos últimos meses. O valor atual representa a quantia, em moeda corrente, de uma carteira teórica de ações, constituída em 2 de janeiro de 1968, a partir de uma aplicação hipotética. Atribuiu-se o valor-base de 100 a um lote-padrão cujo carteira se avoluma sem receber mais nenhum aporte, com o acréscimo exclusivo de proventos gerados pelas ações que compõem o lote-padrão tais como o reinvestimento de dividendos, dos valores recebidos a título de juros sobre capital próprio, o exercício de direitos e recebimento de bonificações, tratando-se de um índice de retorno total.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web

# %%
# !pip install yfinance --upgrade --no-cache-dir

# %%
import yfinance as yf

# %%
yf.pdr_override()

# %% [markdown]
# **Obtendo os Dados**

# %%
ibov = web.get_data_yahoo('^BVSP')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Filter tabela

# %%
ibov.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 1993-04-27  24.799999  25.400000  24.500000  24.500000  24.500000       0
# 1993-04-28  24.500000  24.600000  23.700001  24.299999  24.299999       0
# 1993-04-29  24.299999  24.799999  23.700001  23.700001  23.700001       0
# 1993-04-30  23.700001  24.200001  23.700001  24.100000  24.100000       0
# 1993-05-03  24.100000  24.400000  23.799999  24.100000  24.100000       0

# %%
print(ibov.Open)

# %%
ibov.tail()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2022-08-29  112296.0  113222.0  111689.0  112323.0   112323.0   9795800
# 2022-08-30  112323.0  112869.0  110103.0  110431.0   110431.0  11937900
# 2022-08-31  110431.0  111364.0  109523.0  109523.0   109523.0  14791100
# 2022-09-01  109524.0  110405.0  108217.0  110405.0   110405.0  14478000
# 2022-09-02  110409.0  112264.0  110409.0  110864.0   110864.0         0

# %% [markdown]
# Plot Gráficos

# %%
ibov['Open'].plot(color='teal',figsize=(20,8))
plt.title('Open')
# Out:
# Text(0.5, 1.0, 'Open')

# %% [markdown]
# *Volume*

# %%
ibov['Volume'].plot(color='red',figsize=(20,8))
plt.title('Volume')
# Out:
# Text(0.5, 1.0, 'Volume')

# %%
ibov['Close'].plot(color='green',marker='*',figsize=(20,8))
plt.title('Close')
# Out:
# Text(0.5, 1.0, 'Close')

# %% [markdown]
# **Conclusão**
#
# De acordo com os índices desde 1992 a Ibovespa vem em uma linha de crescimento com pequenas quedas; ressalvo para o ano de 2008 com uma queda relevante e um  volume alto de transações.
# Ano de 2020 uma queda acentuada, com alguns picos de alta à frente e pouca alteração no volume.
